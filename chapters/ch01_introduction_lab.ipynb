# %% [markdown]
# # Chapter 1 Lab: Introduction to AI
#
# ```{admonition} Lab Objectives
# :class: tip
# - Implement various types of AI agents
# - Build and test different agent architectures
# - Simulate agent-environment interactions
# - Compare agent performance metrics
# - Design rational agents for specific tasks
# ```
#
# ## Lab Overview
#
# This lab provides hands-on experience with the fundamental concepts from Chapter 1. You will:
#
# 1. Implement simple reflex agents
# 2. Build model-based agents
# 3. Create goal-based agents
# 4. Design utility-based agents
# 5. Compare agent performance in various environments

# %% [markdown]
# ## Exercise 1: Simple Reflex Agent
#
# Implement a thermostat agent that controls room temperature.

# %%
import random
from typing import Dict, Any

class Environment:
    """Simple environment simulator"""
    def __init__(self, initial_temp: float = 20.0):
        self.temperature = initial_temp
        self.target_temp = 22.0
        
    def step(self, action: str) -> Dict[str, Any]:
        """Apply action and return new percept"""
        # Simulate temperature changes
        if action == 'heat':
            self.temperature += 0.5
        elif action == 'cool':
            self.temperature -= 0.5
        
        # Natural temperature drift
        self.temperature += random.uniform(-0.2, 0.2)
        
        return {
            'temperature': self.temperature,
            'target': self.target_temp
        }

class SimpleReflexAgent:
    """Agent that responds directly to percepts"""
    
    def __init__(self, tolerance: float = 1.0):
        self.tolerance = tolerance
        
    def perceive(self, percept: Dict[str, Any]) -> str:
        """
        TODO: Implement the agent's decision logic
        
        Rules:
        - If temp < target - tolerance: return 'heat'
        - If temp > target + tolerance: return 'cool'
        - Otherwise: return 'idle'
        """
        # YOUR CODE HERE
        pass

# Test your implementation
env = Environment(initial_temp=18.0)
agent = SimpleReflexAgent(tolerance=1.0)

print("Time\tTemp\tAction")
print("-" * 30)

for t in range(20):
    percept = {'temperature': env.temperature, 'target': env.target_temp}
    action = agent.perceive(percept)
    print(f"{t}\t{env.temperature:.1f}°C\t{action}")
    env.step(action)
    
print(f"\nFinal temperature: {env.temperature:.1f}°C")

# %% [markdown]
# ## Exercise 2: Model-Based Agent
#
# Implement a vacuum cleaner agent that maintains an internal model of room cleanliness.

# %%
class VacuumEnvironment:
    """Two-room vacuum environment"""
    def __init__(self):
        self.rooms = {'A': 'dirty', 'B': 'dirty'}
        self.agent_location = 'A'
        self.steps = 0
        
    def step(self, action: str) -> Dict[str, Any]:
        """Execute action and return percept"""
        self.steps += 1
        
        if action == 'suck':
            self.rooms[self.agent_location] = 'clean'
        elif action == 'move_right':
            self.agent_location = 'B'
        elif action == 'move_left':
            self.agent_location = 'A'
            
        return {
            'location': self.agent_location,
            'status': self.rooms[self.agent_location]
        }
        
    def is_clean(self) -> bool:
        return all(status == 'clean' for status in self.rooms.values())

class ModelBasedVacuumAgent:
    """Agent with internal model of environment"""
    
    def __init__(self):
        # Internal model
        self.model = {'A': 'unknown', 'B': 'unknown'}
        self.location = 'A'
        
    def update_model(self, percept: Dict[str, Any]):
        """Update internal model based on percept"""
        # YOUR CODE HERE
        pass
        
    def decide_action(self) -> str:
        """
        TODO: Implement decision logic using the internal model
        
        Strategy:
        1. If current location is dirty, suck
        2. If both rooms known clean, do nothing
        3. Otherwise, move to other room
        """
        # YOUR CODE HERE
        pass

# Test your implementation
env = VacuumEnvironment()
agent = ModelBasedVacuumAgent()

print("Step\tLocation\tStatus\tAction")
print("-" * 50)

step = 0
while not env.is_clean() and step < 10:
    percept = {'location': env.agent_location, 'status': env.rooms[env.agent_location]}
    agent.update_model(percept)
    action = agent.decide_action()
    print(f"{step}\t{percept['location']}\t\t{percept['status']}\t{action}")
    env.step(action)
    step += 1
    
print(f"\nCleaned in {step} steps!")
print(f"Final state: {env.rooms}")

# %% [markdown]
# ## Exercise 3: Goal-Based Agent
#
# Implement a navigation agent that finds paths to goal locations.

# %%
from collections import deque

class GridWorld:
    """Simple grid environment"""
    def __init__(self, size: int = 5):
        self.size = size
        self.agent_pos = (0, 0)
        self.goal_pos = (4, 4)
        self.obstacles = {(1, 1), (2, 2), (3, 1)}
        
    def move(self, action: str) -> bool:
        """Move agent, return True if successful"""
        x, y = self.agent_pos
        
        if action == 'up':
            new_pos = (x, y - 1)
        elif action == 'down':
            new_pos = (x, y + 1)
        elif action == 'left':
            new_pos = (x - 1, y)
        elif action == 'right':
            new_pos = (x + 1, y)
        else:
            return False
            
        # Check bounds and obstacles
        if (0 <= new_pos[0] < self.size and 
            0 <= new_pos[1] < self.size and 
            new_pos not in self.obstacles):
            self.agent_pos = new_pos
            return True
        return False
        
    def at_goal(self) -> bool:
        return self.agent_pos == self.goal_pos

class GoalBasedAgent:
    """Agent that plans to achieve goals"""
    
    def __init__(self, world: GridWorld):
        self.world = world
        self.plan = []
        
    def find_path(self) -> list:
        """
        TODO: Implement BFS to find path from current position to goal
        
        Returns: List of actions ['right', 'down', ...]
        """
        # YOUR CODE HERE
        # Hint: Use BFS from Chapter 2
        pass
        
    def execute_plan(self):
        """Execute the planned actions"""
        if not self.plan:
            self.plan = self.find_path()
            
        if self.plan:
            action = self.plan.pop(0)
            return action
        return None

# Test your implementation
world = GridWorld()
agent = GoalBasedAgent(world)

print("Agent pathfinding from (0,0) to (4,4)")
print(f"Obstacles at: {world.obstacles}")
print()

steps = 0
while not world.at_goal() and steps < 50:
    action = agent.execute_plan()
    if action:
        success = world.move(action)
        print(f"Step {steps}: {action:6s} -> Position {world.agent_pos}")
        steps += 1
    else:
        print("No path found!")
        break
        
if world.at_goal():
    print(f"\n✓ Goal reached in {steps} steps!")

# %% [markdown]
# ## Exercise 4: Utility-Based Agent
#
# Implement an agent that maximizes expected utility.

# %%
import numpy as np

class DeliveryEnvironment:
    """Delivery robot environment"""
    def __init__(self):
        self.packages = {
            'A': {'value': 100, 'time': 5, 'distance': 2},
            'B': {'value': 150, 'time': 10, 'distance': 5},
            'C': {'value': 80, 'time': 3, 'distance': 1}
        }
        self.battery = 100
        self.delivered = []
        
    def deliver(self, package: str) -> float:
        """Deliver package and return utility"""
        if package not in self.packages or package in self.delivered:
            return 0
            
        info = self.packages[package]
        battery_cost = info['distance'] * 5
        
        if self.battery >= battery_cost:
            self.battery -= battery_cost
            self.delivered.append(package)
            return info['value']
        return 0

class UtilityBasedAgent:
    """Agent that maximizes expected utility"""
    
    def __init__(self, env: DeliveryEnvironment):
        self.env = env
        
    def calculate_utility(self, package: str) -> float:
        """
        TODO: Calculate expected utility for delivering this package
        
        Consider:
        - Package value
        - Battery cost (distance * 5)
        - Time efficiency (value / time)
        
        Return a utility score
        """
        # YOUR CODE HERE
        pass
        
    def select_best_action(self) -> str:
        """
        TODO: Select package that maximizes utility
        
        Return: Package ID with highest utility
        """
        # YOUR CODE HERE
        pass

# Test your implementation
env = DeliveryEnvironment()
agent = UtilityBasedAgent(env)

print("Available packages:")
for pkg, info in env.packages.items():
    print(f"{pkg}: Value=${info['value']}, Time={info['time']}min, Distance={info['distance']}km")
    
print(f"\nInitial battery: {env.battery}%")
print("\nDelivery sequence:")

total_value = 0
while env.battery > 0 and len(env.delivered) < len(env.packages):
    package = agent.select_best_action()
    if package:
        utility = agent.calculate_utility(package)
        value = env.deliver(package)
        total_value += value
        print(f"Delivered {package}: ${value} (Utility: {utility:.2f}, Battery: {env.battery}%)")
    else:
        break
        
print(f"\nTotal value delivered: ${total_value}")

# %% [markdown]
# ## Exercise 5: Agent Comparison
#
# Compare the performance of different agent architectures.

# %%
import matplotlib.pyplot as plt
import numpy as np

def evaluate_agent(agent_class, num_trials=100):
    """
    TODO: Evaluate agent performance over multiple trials
    
    Measure:
    - Average steps to complete task
    - Success rate
    - Average utility/reward
    
    Return: Dictionary of metrics
    """
    # YOUR CODE HERE
    pass

# Compare agent types
results = {
    'Simple Reflex': {'steps': [], 'success': [], 'utility': []},
    'Model-Based': {'steps': [], 'success': [], 'utility': []},
    'Goal-Based': {'steps': [], 'success': [], 'utility': []},
    'Utility-Based': {'steps': [], 'success': [], 'utility': []}
}

# YOUR CODE: Run experiments and populate results

# Visualization
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Plot 1: Average steps
agent_types = list(results.keys())
# YOUR CODE: Create bar plot

# Plot 2: Success rate
# YOUR CODE: Create bar plot

# Plot 3: Average utility
# YOUR CODE: Create bar plot

plt.tight_layout()
plt.show()

# Print summary
print("\nAgent Performance Summary:")
print("=" * 60)
# YOUR CODE: Print statistics

# %% [markdown]
# ## Challenge Exercise: Learning Agent
#
# Implement a learning agent that improves over time.

# %%
class LearningAgent:
    """
    Agent that learns from experience using Q-learning basics
    """
    
    def __init__(self, learning_rate=0.1, discount=0.9, epsilon=0.1):
        self.q_table = {}  # State-action values
        self.alpha = learning_rate
        self.gamma = discount
        self.epsilon = epsilon
        
    def get_q_value(self, state, action):
        """Get Q-value for state-action pair"""
        return self.q_table.get((state, action), 0.0)
        
    def update(self, state, action, reward, next_state):
        """
        TODO: Implement Q-learning update rule
        
        Q(s,a) ← Q(s,a) + α[r + γ max_a' Q(s',a') - Q(s,a)]
        """
        # YOUR CODE HERE
        pass
        
    def select_action(self, state, available_actions):
        """
        TODO: Implement ε-greedy action selection
        
        With probability ε: explore (random action)
        Otherwise: exploit (best known action)
        """
        # YOUR CODE HERE
        pass

# Test with grid world
print("Training learning agent...")
# YOUR CODE: Implement training loop

# Compare performance before and after learning
print("\nPerformance comparison:")
# YOUR CODE: Show learning curve

# %% [markdown]
# ## Lab Report
#
# ### Questions for Discussion
#
# 1. **Agent Architectures**:
#    - Which agent type performed best in the vacuum world? Why?
#    - What are the trade-offs between simplicity and intelligence?
#
# 2. **Rationality**:
#    - How did you define "rational behavior" in the delivery problem?
#    - Can a simple reflex agent ever be rational?
#
# 3. **Learning**:
#    - How does the learning agent's performance change over time?
#    - What are the advantages of learning vs. pre-programmed behavior?
#
# 4. **Environment Properties**:
#    - How would partial observability affect your agents?
#    - What if the environment were stochastic instead of deterministic?
#
# ### Deliverables
#
# - [ ] Completed implementation of all agent types
# - [ ] Performance comparison charts
# - [ ] Written analysis (2-3 paragraphs per question)
# - [ ] One additional agent architecture (your design)
#
# ### Additional Challenges
#
# 1. Implement a learning agent for the vacuum world
# 2. Design a multi-agent scenario with cooperation
# 3. Add uncertainty (stochastic transitions) to the grid world
# 4. Create a visualization tool for agent decision-making

# %% [markdown]
# ## Solutions
#
# Complete solutions are available in the instructor repository. Key concepts to remember:
#
# ### Simple Reflex Agent
# ```python
# if percept['temperature'] < percept['target'] - self.tolerance:
#     return 'heat'
# elif percept['temperature'] > percept['target'] + self.tolerance:
#     return 'cool'
# return 'idle'
# ```
#
# ### Model-Based Agent
# - Maintain internal state representation
# - Update model with each percept
# - Use model for decision-making
#
# ### Goal-Based Agent
# - Define explicit goal state
# - Use search (BFS/DFS) to find action sequence
# - Execute plan until goal achieved
#
# ### Utility-Based Agent
# - Calculate utility for each possible action
# - Consider multiple factors (value, cost, time)
# - Select action maximizing expected utility
